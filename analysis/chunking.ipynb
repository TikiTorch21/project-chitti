# %%
import tiktoken
import numpy as np
from openai import OpenAI

# %%
def fixed_tokens(text, chunk_size=100, overlap=20):
    step = chunk_size - overlap
    chunks = []

    for i in range(0, len(text), step):
        chunk = text[i:i+chunk_size]   # slice by characters
        chunks.append(chunk)

        if i + chunk_size >= len(text):
            break

    return chunks

# %%
text = "Hello, my name is Prateek; " * 20
fixed_tokens(text=text)
# Out:
# ['Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is P',
#  ' Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is ',
#  '; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is',
#  'k; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name i',
#  'ek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name ',
#  'eek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name is Prateek; Hello, my name',
#  'teek; Hello, my name is Prateek; Hello, my name is Prateek; ']

# %%
def recursive_char_split(text, chunk_size=200, overlap=20):
    separators = ["\n\n", ". ", " ", ""]   # big → small
    chunks = [text]

    for sep in separators:
        new_chunks = []
        for c in chunks:
            if len(c) <= chunk_size:
                new_chunks.append(c)
            elif sep:  # split by current separator
                parts, cur = [], ""
                for p in c.split(sep):
                    piece = p + sep
                    if len(cur) + len(piece) <= chunk_size:
                        cur += piece
                    else:
                        if cur: new_chunks.append(cur)
                        cur = piece
                if cur: new_chunks.append(cur)
            else:  # last resort: hard cut by chars
                step = chunk_size - overlap
                for i in range(0, len(c), step):
                    new_chunks.append(c[i:i+chunk_size])
        chunks = new_chunks
    return chunks

# %%
sample = "This is a long text. It has multiple sentences. And even paragraphs.\n\nHere is another one."
for i, c in enumerate(recursive_char_split(sample, 40, 10), 1):
    print(f"\nChunk {i}:\n{c}")
# Out:
# Chunk 1:
# This is a long text.
#
# Chunk 2:
# It has multiple sentences.
#
# Chunk 3:
# And even paragraphs.
#
# .
#
# Chunk 4:
# Here is another one.

# %%
def chunks_to_embeddings(chunks, api_key="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", model="text-embedding-3-small"):
    """
    Takes a list of text chunks and returns a list of embeddings.
    API key is passed directly (hard-coded by default).
    """
    client = OpenAI(api_key=api_key)

    response = client.embeddings.create(
        model=model,
        input=chunks
    )
    embeddings = [item.embedding for item in response.data]
    return embeddings

# %%
text = "Hello, my name is Prateek; " * 20
chunks = fixed_tokens(text=text)
chunks_to_embeddings(chunks)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[26], line 3
#       1 text = "Hello, my name is Prateek; " * 20
#       2 chunks = fixed_tokens(text=text)
# ----> 3 chunks_to_embeddings(chunks)
#
# Cell In[25], line 8, in chunks_to_embeddings(chunks, api_key, model)
#       2 """
#       3 Takes a list of text chunks and returns a list of embeddings.
#       4 API key is passed directly (hard-coded by default).
#       5 """
#       6 client = OpenAI(api_key=api_key)
# ----> 8 response = client.embeddings.create(
#       9     model=model,
#      10     input=chunks
#      11 )
#      12 embeddings = [item.embedding for item in response.data]
#      13 return embeddings
#
# ...
